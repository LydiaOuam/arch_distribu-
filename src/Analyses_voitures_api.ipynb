# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os, sys

# %%
cwd = os.getcwd()

# %%
data_voiture = pd.read_csv(cwd+"/data_voiture.csv")

# %%
data_volk = pd.read_csv(cwd+"/news/data_volkswagen.csv")
data_hyun = pd.read_csv(cwd+"/news/data_hyundai.csv")
data_ford = pd.read_csv(cwd+"/news/data_ford.csv")
data_bmw = pd.read_csv(cwd+"/news/data_bmw.csv")
data_toyota = pd.read_csv(cwd+"/news/data_toyota.csv")
data_mercedes = pd.read_csv(cwd+"/news/data_mercedes.csv")

# %%
data_volk.head()
# Out:
#          type          id sentiment_body_p  sentiment_body_s  \
# 0  Volkswagen  5467385760          neutral              0.89
# 1  Volkswagen  5467389216         negative              0.79
# 2  Volkswagen  5467387990         positive              0.92
# 3  Volkswagen  5467376897         positive              0.98
# 4  Volkswagen  5467369616         positive              0.59
#
#   sentiment_title_p  sentiment_title_s             published
# 0          negative               0.80  2023-03-31T21:01:07Z
# 1           neutral               0.48  2023-03-31T20:59:11Z
# 2           neutral               0.62  2023-03-31T20:58:57Z
# 3           neutral               0.77  2023-03-31T20:57:23Z
# 4           neutral               0.54  2023-03-31T20:53:20Z

# %%
data_bmw
# Out:
#    type          id sentiment_body_p  sentiment_body_s sentiment_title_p  \
# 0   bmw  5467445050         positive              0.82           neutral
# 1   bmw  5467444989         positive              0.85           neutral
# 2   bmw  5467443786         positive              0.85           neutral
# 3   bmw  5467443487         positive              0.86           neutral
# 4   bmw  5467443292         positive              0.87           neutral
# ..  ...         ...              ...               ...               ...
# 95  bmw  5467266890         positive              0.76           neutral
# 96  bmw  5467271044         negative              0.95          positive
# 97  bmw  5467282359         negative              0.42           neutral
# 98  bmw  5467269028         positive              0.64           neutral
# 99  bmw  5467268394         positive              0.55           neutral
#
#     sentiment_title_s             published
# 0                0.97  2023-03-31T21:21:50Z
# ...

# %%
data_ford
# Out:
#     type          id sentiment_body_p  sentiment_body_s sentiment_title_p  \
# 0   Ford  5467437877         positive              0.47           neutral
# 1   Ford  5467437887         positive              0.62           neutral
# 2   Ford  5467438051         negative              0.99           neutral
# 3   Ford  5467437652         positive              0.99           neutral
# 4   Ford  5467438218         positive              0.73           neutral
# ..   ...         ...              ...               ...               ...
# 95  Ford  5467382167         negative              0.47           neutral
# 96  Ford  5467381424         positive              0.97           neutral
# 97  Ford  5467384529         negative              0.49           neutral
# 98  Ford  5467383635         negative              0.94           neutral
# 99  Ford  5467383776         positive              0.88           neutral
#
#     sentiment_title_s             published
# ...

# %%
data_toyota
# Out:
#       type          id sentiment_body_p  sentiment_body_s sentiment_title_p  \
# 0   Toyota  5467464128         positive              0.71           neutral
# 1   Toyota  5467463728          neutral              0.44           neutral
# 2   Toyota  5467461138         positive              0.60          negative
# 3   Toyota  5467460898          neutral              1.00           neutral
# 4   Toyota  5467460870         positive              0.99          positive
# ..     ...         ...              ...               ...               ...
# 95  Toyota  5467361573         positive              0.75           neutral
# 96  Toyota  5467361190         positive              0.99           neutral
# 97  Toyota  5467357045         negative              0.81           neutral
# 98  Toyota  5467358049         negative              0.94           neutral
# 99  Toyota  5467355817         positive              0.63           neutral
#
#     sentiment_title_s             published
# ...

# %%
concatt = pd.concat([data_bmw, data_toyota, data_ford, data_hyun, data_mercedes, data_volk])
# , keys=["bmw", "toyota"]

# %%
concatt
# Out:
#           type          id sentiment_body_p  sentiment_body_s  \
# 0          bmw  5467445050         positive              0.82
# 1          bmw  5467444989         positive              0.85
# 2          bmw  5467443786         positive              0.85
# 3          bmw  5467443487         positive              0.86
# 4          bmw  5467443292         positive              0.87
# ..         ...         ...              ...               ...
# 95  Volkswagen  5467244514         positive              0.76
# 96  Volkswagen  5467230926          neutral              0.55
# 97  Volkswagen  5467226839         positive              0.99
# 98  Volkswagen  5467222596         negative              0.96
# 99  Volkswagen  5467222135         positive              0.97
#
#    sentiment_title_p  sentiment_title_s             published
# 0            neutral               0.97  2023-03-31T21:21:50Z
# 1            neutral               0.52  2023-03-31T21:21:39Z
# ...

# %%
# occur_bmw = pd.DataFrame(data_bmw.groupby(['sentiment_body_p']).size(), index = data_bmw["sentiment_body_p"].unique())

# %%
df = concatt.groupby(['type','sentiment_body_p']).agg('count').reset_index()

# %%
df
# Out:
#           type sentiment_body_p  id  sentiment_body_s  sentiment_title_p  \
# 0         Ford         negative  29                29                 29
# 1         Ford          neutral  14                14                 14
# 2         Ford         positive  57                57                 57
# 3      Hyundai         negative  17                17                 17
# 4      Hyundai          neutral  16                16                 16
# 5      Hyundai         positive  67                67                 67
# 6     Mercedes         negative  22                22                 22
# 7     Mercedes          neutral  16                16                 16
# 8     Mercedes         positive  62                62                 62
# 9       Toyota         negative  17                17                 17
# 10      Toyota          neutral  12                12                 12
# 11      Toyota         positive  71                71                 71
# ...

# %%
df_occur = df.pivot(index = "type", columns = 'sentiment_body_p', values = 'id')

# %%
ax = df_occur.plot.bar(stacked=True, figsize=(10,6))

# %%
data_voiture
# Out:
#           model manufacturer  year  price transmission mileage fuelType  tax  \
# 0        Fiesta         Ford  2017  12000    Automatic   15944   Petrol  150
# 1         Focus         Ford  2018  14000       Manual    9083   Petrol  150
# 2         Focus         Ford  2017  13000       Manual   12456   Petrol  150
# 3        Fiesta         Ford  2019  17500       Manual   10460   Petrol  145
# 4        Fiesta         Ford  2019  16500    Automatic    1482   Petrol  145
# ...         ...          ...   ...    ...          ...     ...      ...  ...
# 108545  C Class     Mercedes  2017  14700       Manual   31357   Diesel  1.6
# 108546  C Class     Mercedes  2018  18500    Automatic   28248   Diesel  2.1
# 108547  C Class     Mercedes  2014  11900       Manual   48055   Diesel  2.1
# 108548  C Class     Mercedes  2014  11300    Automatic   49865   Diesel  2.1
# 108549  C Class     Mercedes  2014  14800    Automatic   55445   Diesel  2.1
#
#          mpg engineSize
# ...

# %%
# evolution des prix selon le model (prix , model, annees) pour chaque marque

# %%
# data_voiture.iloc[[17965]]

# %%
data_voiture = data_voiture[data_voiture["price"]!="price"]

# %%
data_voiture
# Out:
#           model manufacturer  year  price transmission mileage fuelType  tax  \
# 0        Fiesta         Ford  2017  12000    Automatic   15944   Petrol  150
# 1         Focus         Ford  2018  14000       Manual    9083   Petrol  150
# 2         Focus         Ford  2017  13000       Manual   12456   Petrol  150
# 3        Fiesta         Ford  2019  17500       Manual   10460   Petrol  145
# 4        Fiesta         Ford  2019  16500    Automatic    1482   Petrol  145
# ...         ...          ...   ...    ...          ...     ...      ...  ...
# 108545  C Class     Mercedes  2017  14700       Manual   31357   Diesel  1.6
# 108546  C Class     Mercedes  2018  18500    Automatic   28248   Diesel  2.1
# 108547  C Class     Mercedes  2014  11900       Manual   48055   Diesel  2.1
# 108548  C Class     Mercedes  2014  11300    Automatic   49865   Diesel  2.1
# 108549  C Class     Mercedes  2014  14800    Automatic   55445   Diesel  2.1
#
#          mpg engineSize
# ...

# %%
# df_price = data_voiture.pivot(index = "manufacturer", columns = 'year', values = 'price')

# %%
# data_voiture[['price', 'year', 'manufacturer']].plot.line(y=['manufacturer'], figsize=(10,6))

# %%
# data_voiture['price'] = pd.to_numeric(data_voiture['price'].str[1:])
# Out:
# C:\Users\pc\AppData\Local\Temp/ipykernel_7484/3872633629.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_voiture['price'] = pd.to_numeric(data_voiture['price'].str[1:])

# %%
dftest = data_voiture.groupby(['manufacturer']).agg('mean').reset_index()

# %%
dftest
# Out:
#   manufacturer        price
# 0         Ford  2932.017806
# 1      Hyundai  2791.489095
# 2     Mercedes  5194.813609
# 3         Opel  1820.094924
# 4        Skoda  3223.606351
# 5       Toyota  2302.978777
# 6   Volkswagen  3787.108333
# 7         audi  4801.353206
# 8          bmw  4683.227994

# %%
dftest.plot.bar(x='manufacturer', y='price', rot=0,figsize=(10,6));

# %%
# moyenne du prix pour marque toyota, ford

# %%
data_voiture['year'].unique()
# Out:
# array(['2017', '2018', '2019', '2015', '2014', '2016', '2013', '2020',
#        '2012', '2008', '2010', '2009', '2011', '1998', '2007', '2005',
#        '2006', '2002', '2003', '1996', '2004', '2000', '2060', 'year',
#        '2001', '1997', '1999', '1970', '1991', '1995'], dtype=object)
